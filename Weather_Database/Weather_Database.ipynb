# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Get the nearest city using the citipy module.
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 732

# %%
# Perform an API call with the OpenWeatherMap.
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather['sys']['country']
        city_description = city_weather["weather"][0]["description"]
                
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          'Country': city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tezu
# Processing Record 2 of Set 1 | tasiilaq
# Processing Record 3 of Set 1 | cidreira
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | goderich
# Processing Record 7 of Set 1 | cap malheureux
# Processing Record 8 of Set 1 | pangnirtung
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | agirish
# Processing Record 11 of Set 1 | norman wells
# Processing Record 12 of Set 1 | korla
# Processing Record 13 of Set 1 | dicabisagan
# Processing Record 14 of Set 1 | faanui
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | the valley
# Processing Record 17 of Set 1 | juneau
# Processing Record 18 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 1 | hofn
# Processing Record 20 of Set 1 | pueblo
# Processing Record 21 of Set 1 | kamenicky senov
# Processing Record 22 of Set 1 | nanortalik
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | chuy
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | deputatskiy
# Processing Record 27 of Set 1 | pak chong
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 1 | souillac
# Processing Record 31 of Set 1 | saskylakh
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | culebra
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | namibe
# Processing Record 36 of Set 1 | nelson bay
# Processing Record 37 of Set 1 | oussouye
# Processing Record 38 of Set 1 | newtownards
# Processing Record 39 of Set 1 | geraldton
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | riberalta
# Processing Record 43 of Set 1 | mount isa
# Processing Record 44 of Set 1 | monrovia
# Processing Record 45 of Set 1 | castro
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | nouakchott
# Processing Record 49 of Set 1 | westerland
# Processing Record 50 of Set 1 | torbay
# Processing Record 1 of Set 2 | lazaro cardenas
# Processing Record 2 of Set 2 | vyatskiye polyany
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | kahului
# Processing Record 5 of Set 2 | myaundzha
# Processing Record 6 of Set 2 | bambous virieux
# Processing Record 7 of Set 2 | pingliang
# Processing Record 8 of Set 2 | fortuna
# Processing Record 9 of Set 2 | makakilo city
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 11 of Set 2 | arraial do cabo
# Processing Record 12 of Set 2 | severo-kurilsk
# Processing Record 13 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 2 | ushuaia
# Processing Record 15 of Set 2 | conceicao das alagoas
# Processing Record 16 of Set 2 | dubenskiy
# City not found. Skipping...
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | chokurdakh
# Processing Record 19 of Set 2 | waingapu
# Processing Record 20 of Set 2 | dikson
# Processing Record 21 of Set 2 | bonfim
# Processing Record 22 of Set 2 | rio cuarto
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | mozarlandia
# Processing Record 25 of Set 2 | mahebourg
# Processing Record 26 of Set 2 | ngunguru
# Processing Record 27 of Set 2 | buritizeiro
# Processing Record 28 of Set 2 | vaini
# Processing Record 29 of Set 2 | anadyr
# Processing Record 30 of Set 2 | kapaa
# Processing Record 31 of Set 2 | atikokan
# Processing Record 32 of Set 2 | saldanha
# Processing Record 33 of Set 2 | cherskiy
# Processing Record 34 of Set 2 | tiksi
# Processing Record 35 of Set 2 | mataura
# Processing Record 36 of Set 2 | margate
# Processing Record 37 of Set 2 | sioux lookout
# Processing Record 38 of Set 2 | aklavik
# Processing Record 39 of Set 2 | tuktoyaktuk
# Processing Record 40 of Set 2 | mar del plata
# Processing Record 41 of Set 2 | kruisfontein
# Processing Record 42 of Set 2 | ondorhaan
# City not found. Skipping...
# Processing Record 43 of Set 2 | cape town
# Processing Record 44 of Set 2 | ponta do sol
# Processing Record 45 of Set 2 | maimon
# City not found. Skipping...
# Processing Record 46 of Set 2 | craig
# Processing Record 47 of Set 2 | constancia
# Processing Record 48 of Set 2 | bathurst
# Processing Record 49 of Set 2 | rawson
# Processing Record 50 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 3 | kavaratti
# Processing Record 2 of Set 3 | bluff
# Processing Record 3 of Set 3 | kirakira
# Processing Record 4 of Set 3 | upernavik
# Processing Record 5 of Set 3 | kaitangata
# Processing Record 6 of Set 3 | saint-michel-des-saints
# Processing Record 7 of Set 3 | oranjemund
# Processing Record 8 of Set 3 | mehamn
# Processing Record 9 of Set 3 | kavieng
# Processing Record 10 of Set 3 | lebu
# Processing Record 11 of Set 3 | ozinki
# Processing Record 12 of Set 3 | sao joao da barra
# Processing Record 13 of Set 3 | constitucion
# Processing Record 14 of Set 3 | muros
# Processing Record 15 of Set 3 | barrow
# Processing Record 16 of Set 3 | wote
# Processing Record 17 of Set 3 | ilhabela
# Processing Record 18 of Set 3 | provideniya
# Processing Record 19 of Set 3 | coolum beach
# Processing Record 20 of Set 3 | leshukonskoye
# Processing Record 21 of Set 3 | ahipara
# Processing Record 22 of Set 3 | gat
# Processing Record 23 of Set 3 | new norfolk
# Processing Record 24 of Set 3 | khatanga
# Processing Record 25 of Set 3 | shubarkuduk
# Processing Record 26 of Set 3 | amapa
# Processing Record 27 of Set 3 | port hardy
# Processing Record 28 of Set 3 | port alfred
# Processing Record 29 of Set 3 | portree
# Processing Record 30 of Set 3 | longyearbyen
# Processing Record 31 of Set 3 | canchungo
# Processing Record 32 of Set 3 | libertador general san martin
# Processing Record 33 of Set 3 | charters towers
# Processing Record 34 of Set 3 | jamestown
# Processing Record 35 of Set 3 | freeport
# Processing Record 36 of Set 3 | airai
# Processing Record 37 of Set 3 | nome
# Processing Record 38 of Set 3 | naze
# Processing Record 39 of Set 3 | atuona
# Processing Record 40 of Set 3 | zhigansk
# Processing Record 41 of Set 3 | xining
# Processing Record 42 of Set 3 | yamada
# Processing Record 43 of Set 3 | pasighat
# Processing Record 44 of Set 3 | sorland
# Processing Record 45 of Set 3 | hay river
# Processing Record 46 of Set 3 | caravelas
# Processing Record 47 of Set 3 | vanderhoof
# Processing Record 48 of Set 3 | nikolskoye
# Processing Record 49 of Set 3 | tres arroyos
# Processing Record 50 of Set 3 | xinzhou
# Processing Record 1 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 4 | havelock
# Processing Record 3 of Set 4 | cayenne
# Processing Record 4 of Set 4 | kozmodemyansk
# Processing Record 5 of Set 4 | ponta delgada
# Processing Record 6 of Set 4 | ust-kulom
# Processing Record 7 of Set 4 | husavik
# Processing Record 8 of Set 4 | east london
# Processing Record 9 of Set 4 | viedma
# Processing Record 10 of Set 4 | imbituba
# Processing Record 11 of Set 4 | lakes entrance
# Processing Record 12 of Set 4 | ugoofaaru
# Processing Record 13 of Set 4 | pevek
# Processing Record 14 of Set 4 | qaanaaq
# Processing Record 15 of Set 4 | bredasdorp
# Processing Record 16 of Set 4 | teguldet
# Processing Record 17 of Set 4 | esperance
# Processing Record 18 of Set 4 | mantua
# Processing Record 19 of Set 4 | houma
# Processing Record 20 of Set 4 | isangel
# Processing Record 21 of Set 4 | iracoubo
# Processing Record 22 of Set 4 | nhulunbuy
# Processing Record 23 of Set 4 | touros
# Processing Record 24 of Set 4 | sibu
# Processing Record 25 of Set 4 | kysyl-syr
# Processing Record 26 of Set 4 | saint-augustin
# Processing Record 27 of Set 4 | marienburg
# Processing Record 28 of Set 4 | belmonte
# Processing Record 29 of Set 4 | outram
# Processing Record 30 of Set 4 | port keats
# Processing Record 31 of Set 4 | vestmanna
# Processing Record 32 of Set 4 | aksarka
# Processing Record 33 of Set 4 | japura
# Processing Record 34 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 4 | iqaluit
# Processing Record 36 of Set 4 | cervo
# Processing Record 37 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 4 | villarrica
# Processing Record 39 of Set 4 | saint george
# Processing Record 40 of Set 4 | petrodvorets
# Processing Record 41 of Set 4 | kaeo
# Processing Record 42 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 4 | laguna
# Processing Record 44 of Set 4 | aykhal
# Processing Record 45 of Set 4 | hasaki
# Processing Record 46 of Set 4 | raga
# Processing Record 47 of Set 4 | maple creek
# Processing Record 48 of Set 4 | sembe
# Processing Record 49 of Set 4 | vila franca do campo
# Processing Record 50 of Set 4 | katsuura
# Processing Record 1 of Set 5 | vanimo
# Processing Record 2 of Set 5 | leningradskiy
# Processing Record 3 of Set 5 | qandala
# Processing Record 4 of Set 5 | sao filipe
# Processing Record 5 of Set 5 | cururupu
# Processing Record 6 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 5 | samarai
# Processing Record 8 of Set 5 | fare
# Processing Record 9 of Set 5 | chumikan
# Processing Record 10 of Set 5 | faya
# Processing Record 11 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 5 | avarua
# Processing Record 13 of Set 5 | bend
# Processing Record 14 of Set 5 | askino
# Processing Record 15 of Set 5 | bengkulu
# Processing Record 16 of Set 5 | igarka
# Processing Record 17 of Set 5 | natal
# Processing Record 18 of Set 5 | rantauprapat
# Processing Record 19 of Set 5 | zyryanka
# Processing Record 20 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 5 | guerrero negro
# Processing Record 22 of Set 5 | quang ngai
# Processing Record 23 of Set 5 | manado
# Processing Record 24 of Set 5 | mukilteo
# Processing Record 25 of Set 5 | kandrian
# Processing Record 26 of Set 5 | kodiak
# Processing Record 27 of Set 5 | chernyy yar
# Processing Record 28 of Set 5 | hermon
# Processing Record 29 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 5 | akyab
# Processing Record 31 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 32 of Set 5 | yar-sale
# Processing Record 33 of Set 5 | ritchie
# Processing Record 34 of Set 5 | jiaohe
# Processing Record 35 of Set 5 | quibor
# Processing Record 36 of Set 5 | mandalgovi
# Processing Record 37 of Set 5 | bethel
# Processing Record 38 of Set 5 | barreirinhas
# Processing Record 39 of Set 5 | dasoguz
# Processing Record 40 of Set 5 | zeya
# Processing Record 41 of Set 5 | kampli
# Processing Record 42 of Set 5 | petapa
# Processing Record 43 of Set 5 | alabaster
# Processing Record 44 of Set 5 | mumford
# Processing Record 45 of Set 5 | nizhniy kuranakh
# Processing Record 46 of Set 5 | leticia
# Processing Record 47 of Set 5 | merauke
# Processing Record 48 of Set 5 | port elizabeth
# Processing Record 49 of Set 5 | susangerd
# Processing Record 50 of Set 5 | atar
# Processing Record 1 of Set 6 | lorengau
# Processing Record 2 of Set 6 | lompoc
# Processing Record 3 of Set 6 | yarada
# Processing Record 4 of Set 6 | urengoy
# Processing Record 5 of Set 6 | kapoeta
# Processing Record 6 of Set 6 | brae
# Processing Record 7 of Set 6 | paamiut
# Processing Record 8 of Set 6 | ballina
# Processing Record 9 of Set 6 | coquimbo
# Processing Record 10 of Set 6 | vryheid
# Processing Record 11 of Set 6 | komsomolskoye
# Processing Record 12 of Set 6 | vao
# Processing Record 13 of Set 6 | butterworth
# Processing Record 14 of Set 6 | porto novo
# Processing Record 15 of Set 6 | champerico
# Processing Record 16 of Set 6 | jasper
# Processing Record 17 of Set 6 | carutapera
# Processing Record 18 of Set 6 | ust-ishim
# Processing Record 19 of Set 6 | angoche
# Processing Record 20 of Set 6 | high level
# Processing Record 21 of Set 6 | bilma
# Processing Record 22 of Set 6 | clyde river
# Processing Record 23 of Set 6 | tenenkou
# Processing Record 24 of Set 6 | lata
# Processing Record 25 of Set 6 | tarauaca
# Processing Record 26 of Set 6 | labuan
# Processing Record 27 of Set 6 | montrose
# Processing Record 28 of Set 6 | cabras
# Processing Record 29 of Set 6 | katangli
# Processing Record 30 of Set 6 | savinka
# Processing Record 31 of Set 6 | bairiki
# Processing Record 32 of Set 6 | te anau
# Processing Record 33 of Set 6 | kushmurun
# Processing Record 34 of Set 6 | sherlovaya gora
# Processing Record 35 of Set 6 | gravdal
# Processing Record 36 of Set 6 | richards bay
# Processing Record 37 of Set 6 | bathsheba
# Processing Record 38 of Set 6 | luena
# Processing Record 39 of Set 6 | ancud
# Processing Record 40 of Set 6 | januaria
# Processing Record 41 of Set 6 | pisco
# Processing Record 42 of Set 6 | carnarvon
# Processing Record 43 of Set 6 | menongue
# Processing Record 44 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 45 of Set 6 | moberly
# Processing Record 46 of Set 6 | najran
# Processing Record 47 of Set 6 | khomutovo
# Processing Record 48 of Set 6 | santa maria del tule
# Processing Record 49 of Set 6 | grand gaube
# Processing Record 50 of Set 6 | asau
# Processing Record 1 of Set 7 | broken hill
# Processing Record 2 of Set 7 | ailigandi
# Processing Record 3 of Set 7 | pahrump
# Processing Record 4 of Set 7 | namwala
# Processing Record 5 of Set 7 | bandiagara
# Processing Record 6 of Set 7 | rio grande
# Processing Record 7 of Set 7 | turbat
# Processing Record 8 of Set 7 | necochea
# Processing Record 9 of Set 7 | comodoro rivadavia
# Processing Record 10 of Set 7 | oksovskiy
# Processing Record 11 of Set 7 | sisimiut
# Processing Record 12 of Set 7 | batagay
# Processing Record 13 of Set 7 | neiafu
# Processing Record 14 of Set 7 | smithers
# Processing Record 15 of Set 7 | dingle
# Processing Record 16 of Set 7 | port augusta
# Processing Record 17 of Set 7 | tomatlan
# Processing Record 18 of Set 7 | rovaniemi
# Processing Record 19 of Set 7 | sao miguel do araguaia
# Processing Record 20 of Set 7 | srandakan
# Processing Record 21 of Set 7 | talaya
# Processing Record 22 of Set 7 | kununurra
# Processing Record 23 of Set 7 | oktyabrskoye
# Processing Record 24 of Set 7 | slavyanka
# Processing Record 25 of Set 7 | otane
# Processing Record 26 of Set 7 | adrar
# Processing Record 27 of Set 7 | aleksandrovka
# Processing Record 28 of Set 7 | ciudad bolivar
# Processing Record 29 of Set 7 | launceston
# Processing Record 30 of Set 7 | abu dhabi
# Processing Record 31 of Set 7 | griffith
# Processing Record 32 of Set 7 | aksarayskiy
# Processing Record 33 of Set 7 | half moon bay
# Processing Record 34 of Set 7 | khairpur
# Processing Record 35 of Set 7 | bandarbeyla
# Processing Record 36 of Set 7 | nizhnyaya omka
# Processing Record 37 of Set 7 | itatiaia
# Processing Record 38 of Set 7 | a
# City not found. Skipping...
# Processing Record 39 of Set 7 | flinders
# Processing Record 40 of Set 7 | yendi
# Processing Record 41 of Set 7 | vestmannaeyjar
# Processing Record 42 of Set 7 | yumen
# Processing Record 43 of Set 7 | dekar
# Processing Record 44 of Set 7 | dauphin
# Processing Record 45 of Set 7 | sikasso
# Processing Record 46 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 47 of Set 7 | morondava
# Processing Record 48 of Set 7 | rena
# Processing Record 49 of Set 7 | klaksvik
# Processing Record 50 of Set 7 | marawi
# Processing Record 1 of Set 8 | agaro
# Processing Record 2 of Set 8 | huancavelica
# Processing Record 3 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 8 | vredendal
# Processing Record 5 of Set 8 | manadhoo
# Processing Record 6 of Set 8 | encruzilhada do sul
# Processing Record 7 of Set 8 | hammerfest
# Processing Record 8 of Set 8 | turukhansk
# Processing Record 9 of Set 8 | san patricio
# Processing Record 10 of Set 8 | talcahuano
# Processing Record 11 of Set 8 | promyshlennaya
# Processing Record 12 of Set 8 | ust-tsilma
# Processing Record 13 of Set 8 | teknaf
# Processing Record 14 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 8 | selma
# Processing Record 16 of Set 8 | uthal
# Processing Record 17 of Set 8 | finschhafen
# Processing Record 18 of Set 8 | mount gambier
# Processing Record 19 of Set 8 | cotusca
# Processing Record 20 of Set 8 | taksimo
# Processing Record 21 of Set 8 | vale
# Processing Record 22 of Set 8 | sidi qasim
# City not found. Skipping...
# Processing Record 23 of Set 8 | port blair
# Processing Record 24 of Set 8 | sitka
# Processing Record 25 of Set 8 | roebourne
# Processing Record 26 of Set 8 | dunedin
# Processing Record 27 of Set 8 | victoria
# Processing Record 28 of Set 8 | larsnes
# Processing Record 29 of Set 8 | tazovskiy
# Processing Record 30 of Set 8 | annau
# Processing Record 31 of Set 8 | kurchum
# Processing Record 32 of Set 8 | alofi
# Processing Record 33 of Set 8 | turtkul
# City not found. Skipping...
# Processing Record 34 of Set 8 | harlingen
# Processing Record 35 of Set 8 | suntar
# Processing Record 36 of Set 8 | port hedland
# Processing Record 37 of Set 8 | marsh harbour
# Processing Record 38 of Set 8 | mackay
# Processing Record 39 of Set 8 | vangaindrano
# Processing Record 40 of Set 8 | santa maria
# Processing Record 41 of Set 8 | salalah
# Processing Record 42 of Set 8 | vila velha
# Processing Record 43 of Set 8 | aktau
# Processing Record 44 of Set 8 | henties bay
# Processing Record 45 of Set 8 | lubao
# Processing Record 46 of Set 8 | tabas
# Processing Record 47 of Set 8 | mackenzie
# Processing Record 48 of Set 8 | tarija
# Processing Record 49 of Set 8 | santa vitoria do palmar
# Processing Record 50 of Set 8 | cabedelo
# Processing Record 1 of Set 9 | vilhena
# Processing Record 2 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 3 of Set 9 | luderitz
# Processing Record 4 of Set 9 | yingshang
# City not found. Skipping...
# Processing Record 5 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 9 | bayir
# Processing Record 8 of Set 9 | luyang
# Processing Record 9 of Set 9 | kamaishi
# Processing Record 10 of Set 9 | umkomaas
# Processing Record 11 of Set 9 | fiumicino
# Processing Record 12 of Set 9 | labuhan
# Processing Record 13 of Set 9 | ulaangom
# Processing Record 14 of Set 9 | marv dasht
# City not found. Skipping...
# Processing Record 15 of Set 9 | lasa
# Processing Record 16 of Set 9 | sept-iles
# Processing Record 17 of Set 9 | maumere
# Processing Record 18 of Set 9 | dom pedrito
# Processing Record 19 of Set 9 | voh
# Processing Record 20 of Set 9 | biak
# Processing Record 21 of Set 9 | ruwi
# Processing Record 22 of Set 9 | karratha
# Processing Record 23 of Set 9 | lena
# Processing Record 24 of Set 9 | coahuayana
# Processing Record 25 of Set 9 | kuli
# Processing Record 26 of Set 9 | cotonou
# Processing Record 27 of Set 9 | wanning
# Processing Record 28 of Set 9 | campbell river
# Processing Record 29 of Set 9 | hithadhoo
# Processing Record 30 of Set 9 | san luis
# Processing Record 31 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 9 | mantang
# Processing Record 33 of Set 9 | codrington
# Processing Record 34 of Set 9 | traverse city
# Processing Record 35 of Set 9 | elko
# Processing Record 36 of Set 9 | lobito
# Processing Record 37 of Set 9 | iluppur
# Processing Record 38 of Set 9 | ziarat
# Processing Record 39 of Set 9 | coihaique
# Processing Record 40 of Set 9 | san cristobal
# Processing Record 41 of Set 9 | batemans bay
# Processing Record 42 of Set 9 | palestrina
# Processing Record 43 of Set 9 | ouango
# Processing Record 44 of Set 9 | jalu
# Processing Record 45 of Set 9 | harda
# Processing Record 46 of Set 9 | poum
# Processing Record 47 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 9 | keti bandar
# Processing Record 49 of Set 9 | camacha
# Processing Record 50 of Set 9 | puerto carreno
# Processing Record 1 of Set 10 | port lincoln
# Processing Record 2 of Set 10 | vardo
# Processing Record 3 of Set 10 | kieta
# Processing Record 4 of Set 10 | bulgan
# Processing Record 5 of Set 10 | birjand
# Processing Record 6 of Set 10 | luwuk
# Processing Record 7 of Set 10 | hubli
# Processing Record 8 of Set 10 | limoges
# Processing Record 9 of Set 10 | fort nelson
# Processing Record 10 of Set 10 | aranos
# Processing Record 11 of Set 10 | ilheus
# Processing Record 12 of Set 10 | honningsvag
# Processing Record 13 of Set 10 | okhotsk
# Processing Record 14 of Set 10 | leeton
# Processing Record 15 of Set 10 | kabare
# Processing Record 16 of Set 10 | egvekinot
# Processing Record 17 of Set 10 | muzhi
# Processing Record 18 of Set 10 | buritama
# Processing Record 19 of Set 10 | sonqar
# City not found. Skipping...
# Processing Record 20 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 10 | marang
# Processing Record 22 of Set 10 | susanville
# Processing Record 23 of Set 10 | shahreza
# Processing Record 24 of Set 10 | bilibino
# Processing Record 25 of Set 10 | parana
# Processing Record 26 of Set 10 | amahai
# Processing Record 27 of Set 10 | kutum
# Processing Record 28 of Set 10 | waitati
# Processing Record 29 of Set 10 | krasnoselkup
# Processing Record 30 of Set 10 | joshimath
# Processing Record 31 of Set 10 | bengkalis
# City not found. Skipping...
# Processing Record 32 of Set 10 | stoyba
# City not found. Skipping...
# Processing Record 33 of Set 10 | maceio
# Processing Record 34 of Set 10 | bage
# Processing Record 35 of Set 10 | bonavista
# Processing Record 36 of Set 10 | russell
# Processing Record 37 of Set 10 | temir
# Processing Record 38 of Set 10 | hamilton
# Processing Record 39 of Set 10 | spodnja idrija
# Processing Record 40 of Set 10 | poopo
# Processing Record 41 of Set 10 | jutai
# Processing Record 42 of Set 10 | tukrah
# Processing Record 43 of Set 10 | elat
# Processing Record 44 of Set 10 | puerto del rosario
# Processing Record 45 of Set 10 | bereznik
# Processing Record 46 of Set 10 | palmer
# Processing Record 47 of Set 10 | itarema
# Processing Record 48 of Set 10 | wahiawa
# Processing Record 49 of Set 10 | beaverlodge
# Processing Record 50 of Set 10 | iquique
# Processing Record 1 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 2 of Set 11 | nishihara
# Processing Record 3 of Set 11 | ternate
# Processing Record 4 of Set 11 | orocue
# Processing Record 5 of Set 11 | peoria
# Processing Record 6 of Set 11 | copiapo
# Processing Record 7 of Set 11 | dalvik
# Processing Record 8 of Set 11 | ferrol
# Processing Record 9 of Set 11 | bemidji
# Processing Record 10 of Set 11 | gombe
# Processing Record 11 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 12 of Set 11 | beringovskiy
# Processing Record 13 of Set 11 | tuatapere
# Processing Record 14 of Set 11 | dubasari
# Processing Record 15 of Set 11 | tambura
# Processing Record 16 of Set 11 | walvis bay
# Processing Record 17 of Set 11 | kouroussa
# Processing Record 18 of Set 11 | goure
# Processing Record 19 of Set 11 | burica
# City not found. Skipping...
# Processing Record 20 of Set 11 | nouadhibou
# Processing Record 21 of Set 11 | christchurch
# Processing Record 22 of Set 11 | sao jose da coroa grande
# Processing Record 23 of Set 11 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 24 of Set 11 | konstantinovo
# Processing Record 25 of Set 11 | bouloupari
# Processing Record 26 of Set 11 | marsa matruh
# Processing Record 27 of Set 11 | daro
# Processing Record 28 of Set 11 | huilong
# Processing Record 29 of Set 11 | lavrentiya
# Processing Record 30 of Set 11 | tammisaari
# Processing Record 31 of Set 11 | villefranche-sur-saone
# Processing Record 32 of Set 11 | arvika
# Processing Record 33 of Set 11 | tulsipur
# Processing Record 34 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 35 of Set 11 | soller
# Processing Record 36 of Set 11 | mali
# Processing Record 37 of Set 11 | baykit
# Processing Record 38 of Set 11 | raahe
# Processing Record 39 of Set 11 | narsaq
# Processing Record 40 of Set 11 | ucluelet
# Processing Record 41 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 42 of Set 11 | todos santos
# Processing Record 43 of Set 11 | sobolevo
# Processing Record 44 of Set 11 | coihueco
# Processing Record 45 of Set 11 | sao cristovao
# Processing Record 46 of Set 11 | la ronge
# Processing Record 47 of Set 11 | mezen
# Processing Record 48 of Set 11 | maragogi
# Processing Record 49 of Set 11 | wilmington
# Processing Record 50 of Set 11 | beaufort
# Processing Record 1 of Set 12 | bonthe
# Processing Record 2 of Set 12 | marand
# Processing Record 3 of Set 12 | taguatinga
# Processing Record 4 of Set 12 | martinsville
# Processing Record 5 of Set 12 | gomel
# Processing Record 6 of Set 12 | corn island
# Processing Record 7 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 8 of Set 12 | eyl
# Processing Record 9 of Set 12 | harper
# Processing Record 10 of Set 12 | waddan
# Processing Record 11 of Set 12 | ambilobe
# Processing Record 12 of Set 12 | ilulissat
# Processing Record 13 of Set 12 | pauini
# Processing Record 14 of Set 12 | bautzen
# Processing Record 15 of Set 12 | bacungan
# Processing Record 16 of Set 12 | axim
# Processing Record 17 of Set 12 | tauramena
# Processing Record 18 of Set 12 | masuguru
# Processing Record 19 of Set 12 | voi
# Processing Record 20 of Set 12 | bollnas
# Processing Record 21 of Set 12 | port said
# Processing Record 22 of Set 12 | ustyuzhna
# Processing Record 23 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 12 | saint anthony
# Processing Record 25 of Set 12 | nabire
# Processing Record 26 of Set 12 | noumea
# Processing Record 27 of Set 12 | ulladulla
# Processing Record 28 of Set 12 | green river
# Processing Record 29 of Set 12 | benghazi
# Processing Record 30 of Set 12 | aktash
# Processing Record 31 of Set 12 | salar
# Processing Record 32 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 12 | tessalit
# Processing Record 34 of Set 12 | ilo
# Processing Record 35 of Set 12 | ketchikan
# Processing Record 36 of Set 12 | college
# Processing Record 37 of Set 12 | rizhao
# Processing Record 38 of Set 12 | camana
# Processing Record 39 of Set 12 | kedrovyy
# Processing Record 40 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 12 | soyo
# Processing Record 42 of Set 12 | oksfjord
# Processing Record 43 of Set 12 | omboue
# Processing Record 44 of Set 12 | san quintin
# Processing Record 45 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 46 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 47 of Set 12 | tshikapa
# Processing Record 48 of Set 12 | maun
# Processing Record 49 of Set 12 | pochutla
# Processing Record 50 of Set 12 | novikovo
# Processing Record 1 of Set 13 | saint stephen
# Processing Record 2 of Set 13 | lagunas
# Processing Record 3 of Set 13 | fez
# Processing Record 4 of Set 13 | kalabo
# Processing Record 5 of Set 13 | cabo san lucas
# Processing Record 6 of Set 13 | alekseyevsk
# Processing Record 7 of Set 13 | urambo
# Processing Record 8 of Set 13 | bangui
# Processing Record 9 of Set 13 | dobrinka
# Processing Record 10 of Set 13 | vadso
# Processing Record 11 of Set 13 | gold coast
# Processing Record 12 of Set 13 | taos
# Processing Record 13 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 14 of Set 13 | port moresby
# Processing Record 15 of Set 13 | pallisa
# Processing Record 16 of Set 13 | hegra
# Processing Record 17 of Set 13 | san marcos
# Processing Record 18 of Set 13 | shar
# Processing Record 19 of Set 13 | tooele
# Processing Record 20 of Set 13 | manzhouli
# Processing Record 21 of Set 13 | takoradi
# Processing Record 22 of Set 13 | verkhnevilyuysk
# Processing Record 23 of Set 13 | batagay-alyta
# Processing Record 24 of Set 13 | karacabey
# Processing Record 25 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 26 of Set 13 | haukipudas
# Processing Record 27 of Set 13 | ust-barguzin
# Processing Record 28 of Set 13 | bukachacha
# Processing Record 29 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 30 of Set 13 | saint-francois
# Processing Record 31 of Set 13 | rabaul
# Processing Record 32 of Set 13 | auki
# Processing Record 33 of Set 13 | roald
# Processing Record 34 of Set 13 | machiques
# Processing Record 35 of Set 13 | vostok
# Processing Record 36 of Set 13 | ikalamavony
# Processing Record 37 of Set 13 | chalan
# Processing Record 38 of Set 13 | port macquarie
# Processing Record 39 of Set 13 | hambantota
# Processing Record 40 of Set 13 | saint andrews
# Processing Record 41 of Set 13 | abalak
# Processing Record 42 of Set 13 | pacific grove
# Processing Record 43 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 44 of Set 13 | cruzeiro do oeste
# Processing Record 45 of Set 13 | dabrowa tarnowska
# Processing Record 46 of Set 13 | la crosse
# Processing Record 47 of Set 13 | tura
# Processing Record 48 of Set 13 | hervey bay
# Processing Record 49 of Set 13 | liverpool
# Processing Record 50 of Set 13 | dolzhanskaya
# Processing Record 1 of Set 14 | ust-koksa
# Processing Record 2 of Set 14 | santa rosalia
# Processing Record 3 of Set 14 | ostrovnoy
# Processing Record 4 of Set 14 | boueni
# Processing Record 5 of Set 14 | fairbanks
# Processing Record 6 of Set 14 | taicheng
# Processing Record 7 of Set 14 | ocos
# Processing Record 8 of Set 14 | mariental
# Processing Record 9 of Set 14 | kaniama
# Processing Record 10 of Set 14 | boyolangu
# Processing Record 11 of Set 14 | kamenka
# Processing Record 12 of Set 14 | bolgar
# Processing Record 13 of Set 14 | emborion
# Processing Record 14 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 15 of Set 14 | malanje
# Processing Record 16 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 14 | arisvi
# Processing Record 18 of Set 14 | suao
# City not found. Skipping...
# Processing Record 19 of Set 14 | espanola
# Processing Record 20 of Set 14 | cananeia
# Processing Record 21 of Set 14 | kungurtug
# Processing Record 22 of Set 14 | magdagachi
# Processing Record 23 of Set 14 | pitimbu
# Processing Record 24 of Set 14 | roma
# Processing Record 25 of Set 14 | chikmagalur
# Processing Record 26 of Set 14 | manokwari
# Processing Record 27 of Set 14 | cockburn town
# Processing Record 28 of Set 14 | velsk
# Processing Record 29 of Set 14 | navirai
# Processing Record 30 of Set 14 | khandbari
# Processing Record 31 of Set 14 | padre paraiso
# Processing Record 32 of Set 14 | poretskoye
# Processing Record 33 of Set 14 | guantanamo
# Processing Record 34 of Set 14 | olga
# Processing Record 35 of Set 14 | atambua
# Processing Record 36 of Set 14 | nynashamn
# Processing Record 37 of Set 14 | yulara
# Processing Record 38 of Set 14 | west bay
# Processing Record 39 of Set 14 | mayo
# Processing Record 40 of Set 14 | lukovetskiy
# Processing Record 41 of Set 14 | redlands
# Processing Record 42 of Set 14 | chapleau
# Processing Record 43 of Set 14 | kloulklubed
# Processing Record 44 of Set 14 | bulawayo
# Processing Record 45 of Set 14 | tilichiki
# Processing Record 46 of Set 14 | bac lieu
# Processing Record 47 of Set 14 | srednekolymsk
# Processing Record 48 of Set 14 | constantine
# Processing Record 49 of Set 14 | kasongo-lunda
# Processing Record 50 of Set 14 | malakal
# Processing Record 1 of Set 15 | san policarpo
# Processing Record 2 of Set 15 | callaway
# Processing Record 3 of Set 15 | saint-leu
# Processing Record 4 of Set 15 | lagoa
# Processing Record 5 of Set 15 | parral
# Processing Record 6 of Set 15 | quelimane
# Processing Record 7 of Set 15 | sinop
# Processing Record 8 of Set 15 | dickinson
# Processing Record 9 of Set 15 | shellbrook
# Processing Record 10 of Set 15 | vihti
# Processing Record 11 of Set 15 | yen bai
# Processing Record 12 of Set 15 | isla mujeres
# Processing Record 13 of Set 15 | alice springs
# Processing Record 14 of Set 15 | quatre cocos
# Processing Record 15 of Set 15 | charlestown
# Processing Record 16 of Set 15 | salinopolis
# Processing Record 17 of Set 15 | awjilah
# Processing Record 18 of Set 15 | oarai
# Processing Record 19 of Set 15 | bagdarin
# Processing Record 20 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 21 of Set 15 | acarau
# Processing Record 22 of Set 15 | neryungri
# Processing Record 23 of Set 15 | vilyuysk
# Processing Record 24 of Set 15 | gamba
# Processing Record 25 of Set 15 | mercedes
# Processing Record 26 of Set 15 | talnakh
# Processing Record 27 of Set 15 | khomeynishahr
# City not found. Skipping...
# Processing Record 28 of Set 15 | babati
# Processing Record 29 of Set 15 | alta floresta
# Processing Record 30 of Set 15 | mega
# Processing Record 31 of Set 15 | yeppoon
# Processing Record 32 of Set 15 | tete
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 674

# %%
# Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Tezu      IN  27.9167   96.1667     75.70        95          99
# 1        Tasiilaq      GL  65.6145  -37.6368     48.36        60          13
# 2        Cidreira      BR -30.1811  -50.2056     60.44        88          28
# 3        Thompson      CA  55.7435  -97.8558     57.36        94         100
# 4         Rikitea      PF -23.1203 -134.9692     72.14        77          83
# 5        Goderich      CA  43.7501  -81.7165     70.92        68          10
# 6  Cap Malheureux      MU -19.9842   57.6142     66.47        76           0
# 7     Pangnirtung      CA  66.1451  -65.7125     48.20        81          75
# 8          Hobart      AU -42.8794  147.3294     52.27        74          75
# 9         Agirish      RU  61.9247   63.0231     56.35        65          24
#
#    Wind Speed Current Description
# 0        3.27     overcast clouds
# 1        4.23          few clouds
# 2        9.33    scattered clouds
# 3        6.91     overcast clouds
# 4       21.72          light rain
# 5        9.22           clear sky
# 6        3.00           clear sky
# 7       11.50       broken clouds
# 8       13.80       broken clouds
# 9        3.91          few clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
